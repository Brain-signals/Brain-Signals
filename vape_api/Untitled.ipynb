# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %%
a=nib.load('p_13_highres_brain.nii').get_fdata()

# %%
plt.imshow(a[:,:,90])

# %%
f = open('p_13_highres_brain.nii', 'rb')

# %%
import vape_model.predict

# %%
tmp = vape_model.predict.predict_from_volume(a)
# Out:
# - uri: models:/vape_mri_3D_wonderbain/None
#
# ✅ model loaded from mlflow

# %%
str(tmp)
# Out:
# '[[1. 0.]]'

# %%
b=nib.load('file.nii').get_fdata()

# %%
b.shape
# Out:
# (256, 256, 150)

# %%
f.
# Out:
# _io.BufferedReader
